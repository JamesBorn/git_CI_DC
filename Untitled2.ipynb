# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (2.21.2)
# Requirement already satisfied: mlflow-skinny==2.21.2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (2.21.2)
# Requirement already satisfied: Flask<4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: numpy<3 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (2.2.4)
# Requirement already satisfied: pandas<3 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (2.0.40)
# Requirement already satisfied: waitress<4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (0.49.0)
# Requirement already satisfied: fastapi<1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (1.31.1)
# Requirement already satisfied: packaging<25 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (2.11.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (4.13.0)
# Requirement already satisfied: uvicorn<1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from mlflow-skinny==2.21.2->mlflow) (0.34.0)
# Requirement already satisfied: Mako in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.9)
# Requirement already satisfied: pywin32>=304 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (11.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: colorama in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.21.2->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow) (2.38.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==2.21.2->mlflow) (0.46.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.2->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.2->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.2->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.2->mlflow) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.2->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.2->mlflow) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.2->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.2->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.2->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.2->mlflow) (2025.1.31)
# Requirement already satisfied: h11>=0.8 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from uvicorn<1->mlflow-skinny==2.21.2->mlflow) (0.14.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.2->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.2->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow) (4.9)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.2->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.2->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pierr\git_cd_ci\git_ci_dc\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.2->mlflow) (0.6.1)

# %%
# !mlflow --version
# Out:
# mlflow, version 2.21.2

# %%
#importation des librairies
import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# !mlflow ui

# %%
# Load dataset
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %%
# Train a model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# configuration de l'uri de mlflow: mlflow-artifacts URI
mlflow.set_tracking_uri('http://localhost:5000')

# %%
# Log the model to MLflow
with mlflow.start_run():
    mlflow.sklearn.log_model(model, "model", registered_model_name="IrisClassifier")
    mlflow.log_metric("accuracy", model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002F3CA28C270>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 871 (4 times)]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002F3CA28C270>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\utils\rest_utils.py:181, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     180 try:
# --> 181     return _get_http_response_with_retries(
#     182         method,
#     183         url,
#     184         max_retries,
#     185         backoff_factor,
#     186         backoff_jitter,
#     187         retry_codes,
#     188         raise_on_status,
#     189         headers=headers,
#     190         verify=host_creds.verify,
#     191         timeout=timeout,
#     192         respect_retry_after_header=respect_retry_after_header,
#     193         **kwargs,
#     194     )
#     195 except requests.exceptions.Timeout as to:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002F3CA28C270>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Log the model to MLflow
# ----> 2 with mlflow.start_run():
#       3     mlflow.sklearn.log_model(model, "model", registered_model_name="IrisClassifier")
#       4     mlflow.log_metric("accuracy", model.score(X_test, y_test))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\tracking\fluent.py:446, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     442         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     444     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 446     active_run_obj = client.create_run(
#     447         experiment_id=exp_id_for_run,
#     448         tags=resolved_tags,
#     449         run_name=run_name,
#     450     )
#     452 if log_system_metrics is None:
#     453     # If `log_system_metrics` is not specified, we will check environment variable.
#     454     log_system_metrics = MLFLOW_ENABLE_SYSTEM_METRICS_LOGGING.get()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\tracking\client.py:393, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     339 def create_run(
#     340     self,
#     341     experiment_id: str,
#    (...)
#     344     run_name: Optional[str] = None,
#     345 ) -> Run:
#     346     """
#     347     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     348     metrics, parameters, artifacts, etc.
#    (...)
#     391         status: RUNNING
#     392     """
# --> 393     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:169, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     164 # Extract user from tags
#     165 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     166 # in a later release.
#     167 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 169 return self.store.create_run(
#     170     experiment_id=experiment_id,
#     171     user_id=user_id,
#     172     start_time=start_time or get_current_time_millis(),
#     173     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     174     run_name=run_name,
#     175 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\store\tracking\rest_store.py:212, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     202 tag_protos = [tag.to_proto() for tag in tags]
#     203 req_body = message_to_json(
#     204     CreateRun(
#     205         experiment_id=str(experiment_id),
#    (...)
#     210     )
#     211 )
# --> 212 response_proto = self._call_endpoint(CreateRun, req_body)
#     213 return Run.from_proto(response_proto.run)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\utils\rest_utils.py:377, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     375 else:
#     376     call_kwargs["json"] = json_body
# --> 377     response = http_request(**call_kwargs)
#     379 response = verify_rest_response(response, endpoint)
#     380 response_to_parse = response.text
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlflow\utils\rest_utils.py:204, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     202     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     203 except Exception as e:
# --> 204     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://localhost:5000/api/2.0/mlflow/runs/create failed with exception HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002F3CA28C270>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))
