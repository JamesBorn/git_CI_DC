# %%
# !pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Requirement already satisfied: configobj in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from fitz) (5.0.9)
# Collecting configparser (from fitz)
#   Downloading configparser-7.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting httplib2 (from fitz)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting nibabel (from fitz)
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting nipype (from fitz)
#   Downloading nipype-1.9.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from fitz) (2.2.1)
# Requirement already satisfied: pandas in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from fitz) (2.2.3)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from fitz) (1.15.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from httplib2->fitz) (3.2.1)
# Requirement already satisfied: packaging>=20 in c:\users\pierr\appdata\roaming\python\python313\site-packages (from nibabel->fitz) (24.2)
# Requirement already satisfied: click>=6.6.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from nipype->fitz) (8.1.8)
# Requirement already satisfied: networkx>=2.5 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from nipype->fitz) (3.4.2)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydot>=1.2.3 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from nipype->fitz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\pierr\appdata\roaming\python\python313\site-packages (from nipype->fitz) (2.9.0.post0)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: simplejson>=3.8.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from nipype->fitz) (3.19.3)
# Collecting traits>=6.2 (from nipype->fitz)
#   Downloading traits-7.0.2-cp313-cp313-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock>=3.0.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from nipype->fitz) (3.17.0)
# Collecting acres (from nipype->fitz)
#   Downloading acres-0.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting etelemetry>=0.3.1 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion!=1.2 (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting puremagic (from nipype->fitz)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from pandas->fitz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from pandas->fitz) (2025.1)
# Requirement already satisfied: lxml>=4.3 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from pyxnat->fitz) (5.3.0)
# Requirement already satisfied: requests>=2.20 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from pyxnat->fitz) (2.32.3)
# Collecting pathlib>=1.0 (from pyxnat->fitz)
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\pierr\appdata\roaming\python\python313\site-packages (from click>=6.6.0->nipype->fitz) (0.4.6)
# Collecting ci-info>=0.2 (from etelemetry>=0.3.1->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-6.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pierr\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->pyxnat->fitz) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->pyxnat->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->pyxnat->fitz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->pyxnat->fitz) (2024.12.14)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configparser-7.1.0-py3-none-any.whl (17 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 3.3/3.3 MB 25.6 MB/s eta 0:00:00
# Downloading nipype-1.9.2-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 43.0 MB/s eta 0:00:00
# Downloading pyxnat-1.6.3-py3-none-any.whl (95 kB)
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Downloading prov-2.0.1-py3-none-any.whl (421 kB)
# Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#    ---------------------------------------- 0.0/528.1 kB ? eta -:--:--
#    --------------------------------------- 528.1/528.1 kB 27.5 MB/s eta 0:00:00
# Downloading traits-7.0.2-cp313-cp313-win_amd64.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 5.0/5.0 MB 34.7 MB/s eta 0:00:00
# Downloading acres-0.3.0-py3-none-any.whl (10 kB)
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Installing collected packages: puremagic, pathlib, looseversion, traits, nibabel, isodate, httplib2, configparser, ci-info, acres, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed acres-0.3.0 ci-info-0.3.0 configparser-7.1.0 etelemetry-0.3.1 fitz-0.0.1.dev2 httplib2-0.22.0 isodate-0.6.1 looseversion-1.3.0 nibabel-5.3.2 nipype-1.9.2 pathlib-1.0.1 prov-2.0.1 puremagic-1.28 pyxnat-1.6.3 rdflib-6.3.2 traits-7.0.2
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install docx
# Out:
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from docx) (5.3.0)
# Requirement already satisfied: Pillow>=2.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from docx) (11.1.0)
# Building wheels for collected packages: docx
#   Building wheel for docx (setup.py): started
#   Building wheel for docx (setup.py): finished with status 'done'
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53938 sha256=226a6376f3fe6f56eea3e2faa8377ba32b3d5d1de3037ebb41f6a5fe5fa33511
#   Stored in directory: c:\users\pierr\appdata\local\pip\cache\wheels\eb\12\a3\0ba9b921d62f8f5253e74a59caa5c11a116bcf497e97eca94c
# Successfully built docx
# Installing collected packages: docx
# Successfully installed docx-0.2.4
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install frontend
# Out:
# Collecting frontend
#   Downloading frontend-0.0.3-py3-none-any.whl.metadata (847 bytes)
# Requirement already satisfied: starlette>=0.12.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from frontend) (0.45.3)
# Requirement already satisfied: uvicorn>=0.7.1 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from frontend) (0.34.0)
# Requirement already satisfied: itsdangerous>=1.1.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from frontend) (2.2.0)
# Collecting aiofiles (from frontend)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from starlette>=0.12.0->frontend) (4.8.0)
# Requirement already satisfied: click>=7.0 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.7.1->frontend) (8.1.8)
# Requirement already satisfied: h11>=0.8 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.7.1->frontend) (0.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.12.0->frontend) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pierr\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.12.0->frontend) (1.3.1)
# Requirement already satisfied: colorama in c:\users\pierr\appdata\roaming\python\python313\site-packages (from click>=7.0->uvicorn>=0.7.1->frontend) (0.4.6)
# Downloading frontend-0.0.3-py3-none-any.whl (32 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Installing collected packages: aiofiles, frontend
# Successfully installed aiofiles-24.1.0 frontend-0.0.3
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fitz  # PyMuPDF
from docx import Document

def pdf_to_word(pdf_path, word_path):
    """Transcribe a PDF document to a Word document."""
    # Open the PDF file
    pdf_document = fitz.open(pdf_path)
    # Create a new Word document
    word_document = Document()

    # Iterate through each page in the PDF
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text = page.get_text("text")
        word_document.add_paragraph(text)

    # Save the Word document
    word_document.save(word_path)

# Example usage
if __name__ == "__main__":
    pdf_path = "example.pdf"
    word_path = "example.docx"
    pdf_to_word(pdf_path, word_path)
    print(f"Transcribed {pdf_path} to {word_path}")
# Out:
# -----------------------------------------------------------
# RuntimeError              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import fitz  # PyMuPDF
#       2 from docx import Document
#       4 def pdf_to_word(pdf_path, word_path):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\__init__.py:1
# ----> 1 from .events import *
#       2 from . import config
#       3 from .components import *
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\events\__init__.py:1
# ----> 1 from .clipboard import *
#       2 from .event_mixins import *
#       3 from .hash_change import *
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\events\clipboard.py:2
#       1 from .event_mixins import ClipboardDataMixin
# ----> 2 from ..dom import Event
#       4 __all__ = ['ClipboardEvent']
#       7 class ClipboardEvent(Event, ClipboardDataMixin):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\dom.py:439
#     435         except KeyError:
#     436             pass
# --> 439 from . import dispatcher
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\dispatcher.py:15
#      12 from starlette.endpoints import WebSocketEndpoint
#      13 from starlette.websockets import WebSocket
# ---> 15 from . import config, server
#      16 from .async_utils import later_await
#      18 __all__ = ['react']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\frontend\server.py:24
#      21 __all__ = ['route', 'run']
#      23 app: Any = Starlette(debug=config.DEBUG)
# ---> 24 app.mount(config.STATIC_ROUTE, StaticFiles(directory=config.STATIC_DIRECTORY), name=config.STATIC_NAME)
#      25 app.add_middleware(GZipMiddleware)
#      26 app.add_middleware(
#      27     CORSMiddleware,
#      28     allow_origins=["*"],
#    (...)
#      31     allow_headers=["*"],
#      32 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\starlette\staticfiles.py:56, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      54 self.follow_symlink = follow_symlink
#      55 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory 'static/' does not exist
