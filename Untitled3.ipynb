# %%
import saspy
print(saspy.__file__)
# Out:
# c:\Users\pierr\git_cd_ci\git_CI_DC\.venv\Lib\site-packages\saspy\__init__.py

# %%
import saspy
sas = saspy.SASsession()
print(sas)
# Out:
# Using SAS Config named: default
# ---------------------------------------------------------------------------
# SASIONotSupportedError                    Traceback (most recent call last)
# Cell In[1], line 2
#       1 import saspy
# ----> 2 sas = saspy.SASsession()
#       3 print(sas)
#
# File c:\Users\pierr\git_cd_ci\git_CI_DC\.venv\Lib\site-packages\saspy\sasbase.py:592, in SASsession.__init__(self, **kwargs)
#     590         self._io = SASsessionSTDIO(sascfgname=self.sascfg.name, sb=self, **kwargs)
#     591     else:
# --> 592         raise SASIONotSupportedError(self.sascfg.mode, alts=['IOM'])
#     593 elif self.sascfg.mode == 'IOM':
#     594     self._io = SASsessionIOM(sascfgname=self.sascfg.name, sb=self, **kwargs)
#
# SASIONotSupportedError: Cannot use STDIO I/O module on Windows. Try the following: IOM
#
# Please refer to the Configuration Instructions in the SASPy Documentation at https://sassoftware.github.io/saspy/configuration
# ...

# %%
# !pwd
# Out:
# /c/Users/pierr/git_cd_ci/git_CI_DC
