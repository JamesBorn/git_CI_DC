# %% [markdown]
# # Installing Jupyter Lab
# This notebook provides instructions to install Jupyter Lab, a powerful interactive development environment for notebooks.

# %%
# Install Jupyter Lab using pip
# !pip install jupyterlab

# %% [markdown]
# ## Verifying Installation
# Run the following command to verify that Jupyter Lab has been installed successfully.

# %%
# Verify Jupyter Lab installation
# !jupyter lab --version

# %% [markdown]
# ## Launching Jupyter Lab
# Use the command below to launch Jupyter Lab in your default web browser.

# %%
# Launch Jupyter Lab
# !jupyter lab
