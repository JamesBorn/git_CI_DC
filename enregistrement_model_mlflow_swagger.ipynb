# %%
#importation des librairies
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# Load dataset
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %%
# Train a model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# configuration de l'uri de mlflow: mlflow-artifacts URI
mlflow.set_tracking_uri('http://localhost:5000')

# %%
# Log the model to MLflow
with mlflow.start_run():
    mlflow.sklearn.log_model(model, "model", registered_model_name="IrisClassifier")
    mlflow.log_metric("accuracy", model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\pierr\git_cd_ci\git_CI_DC\.venv\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\pierr\git_cd_ci\git_CI_DC\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
# !mlflow ui

# %%
#installation de pyenv  necessaire pour l'enregistrement du model
# %USERPROFILE% est utiliser si on travaillle avec powershell
# remplacer %USERPROFILE% par  $HOMEpour git bash on utilise la cmde ci-dessous
#!pip install pyenv-win --target %USERPROFILE%\\.pyenv

# !pip install pyenv-win --target $HOME\\.pyenv
# Out:
# ...
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 3.6/3.6 MB 31.4 MB/s eta 0:00:00
# ...

# %%
# Varibles d'environnement sous window
# creer les variable d'environnement avec les valeurs respectives
# suivantes valide sous windows on peut aussi le faire sous git bash
#variable        valeur
#PYENV           C:\Users\pierr\.pyenv\pyenv-win\
#PYENV_HOME      C:\Users\pierr\.pyenv\pyenv-win\
#PYENV_ROOT      C:\Users\pierr\.pyenv\pyenv-win\
# ajouter les deux chemin dans la variable path
# C:\Users\pierr\.pyenv\pyenv-win\bin et C:\Users\pierr\.pyenv\pyenv-win\shims

# %%
# on peut verifier ensuite si tout est ok avec
# !pyenv --version

# %%
#Create a virtual environment:
# !python -m venv venv
#activate virtual environment:
# !.\venv\Scripts\activate
#install mlflow in virtual environment
# !pip install mlflow
#Run the MLflow model serving command:
# !mlflow models serve -m "models:/IrisClassifier/1" --port 5001

# %%
# Alternative: Use Conda (if installed)
#Create a Conda environment:
# !conda create -n mlflow_env python=3.9 -y
# Activate the environment:
# !conda activate mlflow_env
#Install MLflow dans l'environnement:
# !pip install mlflow
#Run the MLflow model serving command
mlflow models serve -m "models:/IrisClassifier/1" --port 5001

# %%
mlflow models serve -m "models:/IrisClassifier/1" --port 5001

# %%
# configuration des variables system
# !echo 'export PATH="$HOME/.pyenv/pyenv-win/shims:$PATH"' >> ~/.bash_profile
# !echo 'export PATH="$HOME/.pyenv/pyenv-win/bin:$PATH"' >> ~/.bash_profile
# Out:
# Le chemin d'accŠs sp‚cifi‚ est introuvable.
# Le chemin d'accŠs sp‚cifi‚ est introuvable.

# %%
# enregistrement du model
# !mlflow models serve -m "models:/IrisClassifier/1" --port 5001
# Out:
# ...
# 2025/04/01 20:50:54 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
#
# ...
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\pierr\AppData\Local\Programs\Python\Python313\Scripts\mlflow.exe\__main__.py", line 7, in <module>
#     sys.exit(cli())
#              ~~~^^
#   File "C:\Users\pierr\AppData\Local\Programs\Python\Python313\Lib\site-packages\click\core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\pierr\AppData\Local\Programs\Python\Python313\Lib\site-packages\click\core.py", line 1082, in main
#     rv = self.invoke(ctx)
#   File "C:\Users\pierr\AppData\Local\Programs\Python\Python313\Lib\site-packages\click\core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
# ...
