# %% [markdown]
# # Integrating Git Bash and Git into JupyterLab
# This notebook provides steps to integrate Git Bash and Git functionality into JupyterLab.

# %% [markdown]
# ## Step 1: Install JupyterLab Git Extension
# Install the JupyterLab Git extension to enable Git integration.

# %%
# Install JupyterLab Git extension
# !pip install jupyterlab-git

# %% [markdown]
# ## Step 2: Enable the Git Extension
# Enable the Git extension in JupyterLab using the following command.

# %%
# Enable the Git extension
# !jupyter labextension install @jupyterlab/git

# %% [markdown]
# ## Step 3: Install Git Bash
# Ensure Git Bash is installed on your system. You can download it from [Git Bash Download](https://git-scm.com/).

# %% [markdown]
# ## Step 4: Configure JupyterLab to Use Git Bash
# Modify the JupyterLab configuration to use Git Bash as the default terminal.

# %%
# Locate the Jupyter configuration directory
# !jupyter --config-dir

# %%
# Edit the Jupyter configuration file to set Git Bash as the default terminal
# Example configuration (adjust the path to Git Bash as needed):
c.NotebookApp.terminado_settings = {
    'shell_command': ['C:\\Program Files\\Git\\bin\\bash.exe']
}

# %% [markdown]
# ## Step 5: Restart JupyterLab
# Restart JupyterLab to apply the changes and verify that Git Bash is now the default terminal.
